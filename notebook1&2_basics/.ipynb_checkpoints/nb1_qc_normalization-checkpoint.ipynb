# %% [markdown]
# # QC and Normalisation

# %% [markdown]
# In this notebook, we will look at basic pre-processing of scRNA-seq data. We'll cover the topics of:
# - QC
# - Data normalization
#
# Adjusted from: [scverse - GSCN workshop](https://github.com/scverse/202510_workshop_GSCN/tree/main)

# %% [markdown]
# # Library imports

# %% [markdown]
# Install all packages for the tutorial

# %%
! pip install lamindb
# Out:
# Requirement already satisfied: lamindb in c:\users\lisap\anaconda3\lib\site-packages (1.16.2)
# Requirement already satisfied: lamin_utils==0.15.0 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb) (0.15.0)
# Requirement already satisfied: lamin_cli==1.9.0 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb) (1.9.0)
# Requirement already satisfied: lamindb_setup==1.15.2 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb_setup[aws]==1.15.2->lamindb) (1.15.2)
# Requirement already satisfied: bionty==1.9.1 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb) (1.9.1)
# Requirement already satisfied: wetlab==1.6.1 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb) (1.6.1)
# Requirement already satisfied: nbproject==0.11.1 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb) (0.11.1)
# Requirement already satisfied: jupytext in c:\users\lisap\anaconda3\lib\site-packages (from lamindb) (1.18.1)
# Requirement already satisfied: nbconvert>=7.2.1 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb) (7.16.6)
# Requirement already satisfied: pyyaml in c:\users\lisap\anaconda3\lib\site-packages (from lamindb) (6.0.2)
# Requirement already satisfied: pyarrow in c:\users\lisap\anaconda3\lib\site-packages (from lamindb) (19.0.0)
# Requirement already satisfied: pandera>=0.24.0 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb) (0.26.1)
# Requirement already satisfied: typing_extensions!=4.6.0 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb) (4.15.0)
# Requirement already satisfied: python-dateutil in c:\users\lisap\anaconda3\lib\site-packages (from lamindb) (2.9.0.post0)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb) (2.2.3)
# Requirement already satisfied: anndata<=0.12.5,>=0.8.0 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb) (0.12.5)
# Requirement already satisfied: fsspec in c:\users\lisap\anaconda3\lib\site-packages (from lamindb) (2025.3.2)
# Requirement already satisfied: graphviz in c:\users\lisap\anaconda3\lib\site-packages (from lamindb) (0.21)
# Requirement already satisfied: psycopg2-binary in c:\users\lisap\anaconda3\lib\site-packages (from lamindb) (2.9.11)
# Requirement already satisfied: requests in c:\users\lisap\anaconda3\lib\site-packages (from bionty==1.9.1->lamindb) (2.32.3)
# Requirement already satisfied: rich-click>=1.7 in c:\users\lisap\anaconda3\lib\site-packages (from lamin_cli==1.9.0->lamindb) (1.9.4)
# Requirement already satisfied: django<5.3,>=5.2 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (5.2.8)
# Requirement already satisfied: dj_database_url<3.0.0,>=1.3.0 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (2.3.0)
# Requirement already satisfied: pydantic-settings in c:\users\lisap\anaconda3\lib\site-packages (from lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (2.6.1)
# Requirement already satisfied: platformdirs<5.0.0 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (4.3.7)
# Requirement already satisfied: httpx_retries<1.0.0 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (0.4.5)
# Requirement already satisfied: universal_pathlib==0.2.6 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (0.2.6)
# Requirement already satisfied: botocore<2.0.0 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (1.36.3)
# Requirement already satisfied: supabase<=2.16.0,>=2.8.1 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (2.16.0)
# Requirement already satisfied: gotrue<=2.12.0 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (2.12.0)
# Requirement already satisfied: pyjwt<3.0.0 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (2.10.1)
# Requirement already satisfied: psutil in c:\users\lisap\anaconda3\lib\site-packages (from lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (5.9.0)
# Requirement already satisfied: packaging in c:\users\lisap\anaconda3\lib\site-packages (from lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (24.2)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.12.4 in c:\users\lisap\anaconda3\lib\site-packages (from aiobotocore[boto3]<3.0.0,>=2.12.4; extra == "aws"->lamindb_setup[aws]==1.15.2->lamindb) (2.19.0)
# Requirement already satisfied: s3fs!=2024.10.0,<=2025.9.0,>=2023.12.2 in c:\users\lisap\anaconda3\lib\site-packages (from lamindb_setup[aws]==1.15.2->lamindb) (2025.3.2)
# Requirement already satisfied: pydantic>=2.0.0 in c:\users\lisap\anaconda3\lib\site-packages (from nbproject==0.11.1->lamindb) (2.11.7)
# Requirement already satisfied: orjson in c:\users\lisap\anaconda3\lib\site-packages (from nbproject==0.11.1->lamindb) (3.11.4)
# Requirement already satisfied: importlib-metadata in c:\users\lisap\anaconda3\lib\site-packages (from nbproject==0.11.1->lamindb) (8.5.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.2 in c:\users\lisap\anaconda3\lib\site-packages (from aiobotocore<3.0.0,>=2.12.4->aiobotocore[boto3]<3.0.0,>=2.12.4; extra == "aws"->lamindb_setup[aws]==1.15.2->lamindb) (3.11.10)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in c:\users\lisap\anaconda3\lib\site-packages (from aiobotocore<3.0.0,>=2.12.4->aiobotocore[boto3]<3.0.0,>=2.12.4; extra == "aws"->lamindb_setup[aws]==1.15.2->lamindb) (0.7.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\lisap\anaconda3\lib\site-packages (from aiobotocore<3.0.0,>=2.12.4->aiobotocore[boto3]<3.0.0,>=2.12.4; extra == "aws"->lamindb_setup[aws]==1.15.2->lamindb) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in c:\users\lisap\anaconda3\lib\site-packages (from aiobotocore<3.0.0,>=2.12.4->aiobotocore[boto3]<3.0.0,>=2.12.4; extra == "aws"->lamindb_setup[aws]==1.15.2->lamindb) (6.1.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\lisap\anaconda3\lib\site-packages (from aiobotocore<3.0.0,>=2.12.4->aiobotocore[boto3]<3.0.0,>=2.12.4; extra == "aws"->lamindb_setup[aws]==1.15.2->lamindb) (2.3.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in c:\users\lisap\anaconda3\lib\site-packages (from aiobotocore<3.0.0,>=2.12.4->aiobotocore[boto3]<3.0.0,>=2.12.4; extra == "aws"->lamindb_setup[aws]==1.15.2->lamindb) (1.17.0)
# Requirement already satisfied: boto3<1.36.4,>=1.36.0 in c:\users\lisap\anaconda3\lib\site-packages (from aiobotocore[boto3]<3.0.0,>=2.12.4; extra == "aws"->lamindb_setup[aws]==1.15.2->lamindb) (1.36.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lisap\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore<3.0.0,>=2.12.4->aiobotocore[boto3]<3.0.0,>=2.12.4; extra == "aws"->lamindb_setup[aws]==1.15.2->lamindb) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lisap\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore<3.0.0,>=2.12.4->aiobotocore[boto3]<3.0.0,>=2.12.4; extra == "aws"->lamindb_setup[aws]==1.15.2->lamindb) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lisap\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore<3.0.0,>=2.12.4->aiobotocore[boto3]<3.0.0,>=2.12.4; extra == "aws"->lamindb_setup[aws]==1.15.2->lamindb) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lisap\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore<3.0.0,>=2.12.4->aiobotocore[boto3]<3.0.0,>=2.12.4; extra == "aws"->lamindb_setup[aws]==1.15.2->lamindb) (1.5.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lisap\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore<3.0.0,>=2.12.4->aiobotocore[boto3]<3.0.0,>=2.12.4; extra == "aws"->lamindb_setup[aws]==1.15.2->lamindb) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\lisap\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore<3.0.0,>=2.12.4->aiobotocore[boto3]<3.0.0,>=2.12.4; extra == "aws"->lamindb_setup[aws]==1.15.2->lamindb) (1.18.0)
# Requirement already satisfied: array-api-compat>=1.7.1 in c:\users\lisap\anaconda3\lib\site-packages (from anndata<=0.12.5,>=0.8.0->lamindb) (1.12.0)
# Requirement already satisfied: h5py>=3.8 in c:\users\lisap\anaconda3\lib\site-packages (from anndata<=0.12.5,>=0.8.0->lamindb) (3.12.1)
# Requirement already satisfied: legacy-api-wrap in c:\users\lisap\anaconda3\lib\site-packages (from anndata<=0.12.5,>=0.8.0->lamindb) (1.5)
# Requirement already satisfied: natsort in c:\users\lisap\anaconda3\lib\site-packages (from anndata<=0.12.5,>=0.8.0->lamindb) (8.4.0)
# Requirement already satisfied: numpy>=1.26 in c:\users\lisap\anaconda3\lib\site-packages (from anndata<=0.12.5,>=0.8.0->lamindb) (2.1.3)
# Requirement already satisfied: scipy>=1.12 in c:\users\lisap\anaconda3\lib\site-packages (from anndata<=0.12.5,>=0.8.0->lamindb) (1.15.3)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in c:\users\lisap\anaconda3\lib\site-packages (from anndata<=0.12.5,>=0.8.0->lamindb) (3.1.3)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in c:\users\lisap\anaconda3\lib\site-packages (from boto3<1.36.4,>=1.36.0->aiobotocore[boto3]<3.0.0,>=2.12.4; extra == "aws"->lamindb_setup[aws]==1.15.2->lamindb) (0.11.3)
# Requirement already satisfied: asgiref>=3.8.1 in c:\users\lisap\anaconda3\lib\site-packages (from django<5.3,>=5.2->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (3.10.0)
# Requirement already satisfied: sqlparse>=0.3.1 in c:\users\lisap\anaconda3\lib\site-packages (from django<5.3,>=5.2->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (0.5.3)
# Requirement already satisfied: tzdata in c:\users\lisap\anaconda3\lib\site-packages (from django<5.3,>=5.2->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (2025.2)
# Requirement already satisfied: httpx<0.29,>=0.26 in c:\users\lisap\anaconda3\lib\site-packages (from httpx[http2]<0.29,>=0.26->gotrue<=2.12.0->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (0.28.1)
# Requirement already satisfied: pytest-mock<4.0.0,>=3.14.0 in c:\users\lisap\anaconda3\lib\site-packages (from gotrue<=2.12.0->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (3.15.1)
# Requirement already satisfied: anyio in c:\users\lisap\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->httpx[http2]<0.29,>=0.26->gotrue<=2.12.0->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (4.7.0)
# Requirement already satisfied: certifi in c:\users\lisap\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->httpx[http2]<0.29,>=0.26->gotrue<=2.12.0->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\lisap\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->httpx[http2]<0.29,>=0.26->gotrue<=2.12.0->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (1.0.9)
# Requirement already satisfied: idna in c:\users\lisap\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->httpx[http2]<0.29,>=0.26->gotrue<=2.12.0->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\lisap\anaconda3\lib\site-packages (from httpcore==1.*->httpx<0.29,>=0.26->httpx[http2]<0.29,>=0.26->gotrue<=2.12.0->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\lisap\anaconda3\lib\site-packages (from httpx[http2]<0.29,>=0.26->gotrue<=2.12.0->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\lisap\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->gotrue<=2.12.0->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\lisap\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->gotrue<=2.12.0->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (4.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lisap\anaconda3\lib\site-packages (from pydantic>=2.0.0->nbproject==0.11.1->lamindb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\lisap\anaconda3\lib\site-packages (from pydantic>=2.0.0->nbproject==0.11.1->lamindb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\lisap\anaconda3\lib\site-packages (from pydantic>=2.0.0->nbproject==0.11.1->lamindb) (0.4.2)
# Requirement already satisfied: pytest>=6.2.5 in c:\users\lisap\anaconda3\lib\site-packages (from pytest-mock<4.0.0,>=3.14.0->gotrue<=2.12.0->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (8.3.4)
# Requirement already satisfied: six>=1.5 in c:\users\lisap\anaconda3\lib\site-packages (from python-dateutil->lamindb) (1.17.0)
# Requirement already satisfied: postgrest<1.2,>0.19 in c:\users\lisap\anaconda3\lib\site-packages (from supabase<=2.16.0,>=2.8.1->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (1.1.1)
# Requirement already satisfied: realtime<2.6.0,>=2.4.0 in c:\users\lisap\anaconda3\lib\site-packages (from supabase<=2.16.0,>=2.8.1->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (2.5.3)
# Requirement already satisfied: storage3<0.13,>=0.10 in c:\users\lisap\anaconda3\lib\site-packages (from supabase<=2.16.0,>=2.8.1->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (0.12.2)
# Requirement already satisfied: supafunc<0.11,>=0.9 in c:\users\lisap\anaconda3\lib\site-packages (from supabase<=2.16.0,>=2.8.1->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (0.10.2)
# Requirement already satisfied: deprecation<3.0.0,>=2.1.0 in c:\users\lisap\anaconda3\lib\site-packages (from postgrest<1.2,>0.19->supabase<=2.16.0,>=2.8.1->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (2.1.0)
# Requirement already satisfied: websockets<16,>=11 in c:\users\lisap\anaconda3\lib\site-packages (from realtime<2.6.0,>=2.4.0->supabase<=2.16.0,>=2.8.1->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (15.0.1)
# Requirement already satisfied: strenum<0.5.0,>=0.4.15 in c:\users\lisap\anaconda3\lib\site-packages (from supafunc<0.11,>=0.9->supabase<=2.16.0,>=2.8.1->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (0.4.15)
# Requirement already satisfied: beautifulsoup4 in c:\users\lisap\anaconda3\lib\site-packages (from nbconvert>=7.2.1->lamindb) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\lisap\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=7.2.1->lamindb) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\lisap\anaconda3\lib\site-packages (from nbconvert>=7.2.1->lamindb) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\lisap\anaconda3\lib\site-packages (from nbconvert>=7.2.1->lamindb) (3.1.6)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\lisap\anaconda3\lib\site-packages (from nbconvert>=7.2.1->lamindb) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\lisap\anaconda3\lib\site-packages (from nbconvert>=7.2.1->lamindb) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\lisap\anaconda3\lib\site-packages (from nbconvert>=7.2.1->lamindb) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\lisap\anaconda3\lib\site-packages (from nbconvert>=7.2.1->lamindb) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\lisap\anaconda3\lib\site-packages (from nbconvert>=7.2.1->lamindb) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in c:\users\lisap\anaconda3\lib\site-packages (from nbconvert>=7.2.1->lamindb) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\lisap\anaconda3\lib\site-packages (from nbconvert>=7.2.1->lamindb) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\lisap\anaconda3\lib\site-packages (from nbconvert>=7.2.1->lamindb) (2.19.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\lisap\anaconda3\lib\site-packages (from nbconvert>=7.2.1->lamindb) (5.14.3)
# Requirement already satisfied: webencodings in c:\users\lisap\anaconda3\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=7.2.1->lamindb) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\lisap\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=7.2.1->lamindb) (1.4.0)
# Requirement already satisfied: pywin32>=300 in c:\users\lisap\anaconda3\lib\site-packages (from jupyter-core>=4.7->nbconvert>=7.2.1->lamindb) (308)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\lisap\anaconda3\lib\site-packages (from nbclient>=0.5.0->nbconvert>=7.2.1->lamindb) (8.6.3)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\lisap\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=7.2.1->lamindb) (26.2.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\lisap\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=7.2.1->lamindb) (6.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\lisap\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert>=7.2.1->lamindb) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\lisap\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert>=7.2.1->lamindb) (4.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lisap\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=7.2.1->lamindb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lisap\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=7.2.1->lamindb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lisap\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=7.2.1->lamindb) (0.22.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lisap\anaconda3\lib\site-packages (from pandas>=2.0.0->lamindb) (2024.1)
# Requirement already satisfied: typeguard in c:\users\lisap\anaconda3\lib\site-packages (from pandera>=0.24.0->lamindb) (4.4.4)
# Requirement already satisfied: typing_inspect>=0.6.0 in c:\users\lisap\anaconda3\lib\site-packages (from pandera>=0.24.0->lamindb) (0.9.0)
# Requirement already satisfied: colorama in c:\users\lisap\anaconda3\lib\site-packages (from pytest>=6.2.5->pytest-mock<4.0.0,>=3.14.0->gotrue<=2.12.0->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (0.4.6)
# Requirement already satisfied: iniconfig in c:\users\lisap\anaconda3\lib\site-packages (from pytest>=6.2.5->pytest-mock<4.0.0,>=3.14.0->gotrue<=2.12.0->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (1.1.1)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\lisap\anaconda3\lib\site-packages (from pytest>=6.2.5->pytest-mock<4.0.0,>=3.14.0->gotrue<=2.12.0->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (1.5.0)
# Requirement already satisfied: click>=8 in c:\users\lisap\anaconda3\lib\site-packages (from rich-click>=1.7->lamin_cli==1.9.0->lamindb) (8.1.8)
# Requirement already satisfied: rich>=12 in c:\users\lisap\anaconda3\lib\site-packages (from rich-click>=1.7->lamin_cli==1.9.0->lamindb) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lisap\anaconda3\lib\site-packages (from rich>=12->rich-click>=1.7->lamin_cli==1.9.0->lamindb) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lisap\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12->rich-click>=1.7->lamin_cli==1.9.0->lamindb) (0.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\lisap\anaconda3\lib\site-packages (from typing_inspect>=0.6.0->pandera>=0.24.0->lamindb) (1.0.0)
# Requirement already satisfied: donfig>=0.8 in c:\users\lisap\anaconda3\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata<=0.12.5,>=0.8.0->lamindb) (0.8.1.post1)
# Requirement already satisfied: numcodecs>=0.14 in c:\users\lisap\anaconda3\lib\site-packages (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata<=0.12.5,>=0.8.0->lamindb) (0.16.3)
# Requirement already satisfied: crc32c>=2.7 in c:\users\lisap\anaconda3\lib\site-packages (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata<=0.12.5,>=0.8.0->lamindb) (2.8)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lisap\anaconda3\lib\site-packages (from anyio->httpx<0.29,>=0.26->httpx[http2]<0.29,>=0.26->gotrue<=2.12.0->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lisap\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=7.2.1->lamindb) (2.5)
# Requirement already satisfied: zipp>=3.20 in c:\users\lisap\anaconda3\lib\site-packages (from importlib-metadata->nbproject==0.11.1->lamindb) (3.21.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\lisap\anaconda3\lib\site-packages (from jupytext->lamindb) (0.3.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\lisap\anaconda3\lib\site-packages (from pydantic-settings->lamindb_setup==1.15.2->lamindb_setup[aws]==1.15.2->lamindb) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lisap\anaconda3\lib\site-packages (from requests->bionty==1.9.1->lamindb) (3.3.2)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import os

# single cell library
import scanpy as sc

# doublet detection
import scrublet as scr

# data loading
import lamindb as ln
# Out:
# ! not connected, call: ln.connect('account/name')

# %% [markdown]
# # Load data

# %% [markdown]
# We use [Lamin](https://docs.lamin.ai/introduction) to load the data.
#
# Overview of available datasets in lamin instance, in our case [theislab/ad_jaekel](https://lamin.ai/theislab/ad_jaekel)

# %%
ln.setup.login("lisa.pelzl@tum.de")
# Out:
# Current user:
#  - handle: lisapelzl
#  - uid: 8kBsgq2L

# %%
ln.connect("theislab/ad_jaekel")
# Out:
# → connected lamindb: theislab/ad_jaekel
# • to map a local dev directory, set: ln.setup.settings.dev_dir = '.'

# %%
ln.Artifact.df()
# Out:
# C:\Users\lisap\AppData\Local\Temp\ipykernel_10568\3926378802.py:1: DeprecationWarning: Use to_dataframe instead of df, df will be removed in the future.
#   ln.Artifact.df()
#                      uid                     key  \
# id
# 1   7YRPApRIFl4LOsaj0000  drummer_jaekel_25.h5ad
#
#                                      description suffix     kind    otype  \
# id
# 1   snRNA-seq data from control and AD patients.  .h5ad  dataset  AnnData
#
#            size                    hash n_files  n_observations version  \
# id
# 1   18151628738  A_Cuc4pPkMRXn_IaJ-IW7W    None           26598    None
#
#     is_latest  is_locked                       created_at  branch_id  \
# id
# 1        True      False 2025-11-06 17:18:14.701436+00:00          1
#
#     space_id  storage_id run_id schema_id  created_by_id
# id
# 1          1           1   None      None              7

# %%
# Get the artifact
artifact = ln.Artifact.get("7YRPApRIFl4LOsaj0000")

# Load the AnnData object into memory
adata = artifact.load()
# Out:
# ! run input wasn't tracked, call `ln.track()` and re-run

# %% [markdown]
# Clean up the adata object to immitade a unprocessed object.

# %%
obs_cols_to_keep = [
    'sample', 'condition', 'area', 'age', 'donor', 
    'sequencing batch', 'sequencing id', 'sex', 
    'APOE genotype', 'brain area number', 'running number', 
    'donor_v2', 'donor_v2_area', 'tech_sample', 'cell_type'
]

var_cols_to_keep = ['ensemble_id', 'Accession', 'Chromosome', 'End', 'Start', 'Strand']

# Delete unwanted obs columns
obs_cols_to_delete = [col for col in adata.obs.columns if col not in obs_cols_to_keep]
for col in obs_cols_to_delete:
    del adata.obs[col]

# Delete all var columns (keep only the index)
var_cols_to_delete = [col for col in adata.var.columns if col not in var_cols_to_keep]
for var in list(var_cols_to_delete):
    del adata.var[var]

# Delete all other slots
del adata.uns
del adata.obsm
del adata.varm
del adata.layers
del adata.obsp

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 26598 × 34802
#     obs: 'sample', 'condition', 'area', 'age', 'donor', 'sequencing batch', 'sequencing id', 'sex', 'APOE genotype', 'brain area number', 'running number', 'donor_v2', 'donor_v2_area', 'tech_sample', 'cell_type'
#     var: 'ensemble_id', 'Accession', 'Chromosome', 'End', 'Start', 'Strand'

# %%
adata.var
# Out:
#                      ensemble_id        Accession  Chromosome       End  \
# gene_symbol
# PRDM16                    PRDM16  ENSG00000142611           1   3438621
# PEX10                      PEX10  ENSG00000157911           1   2413797
# PEX14                      PEX14  ENSG00000142655           1  10630758
# PLCH2                      PLCH2  ENSG00000149527           1   2505532
# SPSB1                      SPSB1  ENSG00000171621           1   9369532
# ...                          ...              ...         ...       ...
# ENSG00000298139  ENSG00000298139  ENSG00000298139  KI270713.1     25193
# ENSG00000298153  ENSG00000298153  ENSG00000298153  KI270713.1     22304
# ENSG00000298169  ENSG00000298169  ENSG00000298169  KI270713.1      7142
# ENSG00000302039  ENSG00000302039  ENSG00000302039  KI270720.1     31375
# ENSG00000309831  ENSG00000309831  ENSG00000309831  KI270718.1     19848
#
#                     Start Strand
# gene_symbol
# PRDM16            3069168      +
# PEX10             2403964      -
# PEX14            10472288      +
# PLCH2             2425980      +
# SPSB1             9292894      +
# ...                   ...    ...
# ENSG00000298139     13389      +
# ENSG00000298153     11685      -
# ENSG00000298169      4168      +
# ENSG00000302039      3633      -
# ENSG00000309831      6913      -
#
# [34802 rows x 6 columns]

# %% [markdown]
# # Basic pre-processing of data

# %% [markdown]
# Data quality control can be split into cell QC and gene QC. Typical quality measures for assessing the quality of a cell include the number of molecule counts (UMIs), the number of expressed genes, and the fraction of counts that are mitochondrial. A high fraction of mitochondrial reads being picked up can indicate cell stress, as there is a low proportion of nuclear mRNA in the cell. It should be noted that high mitochondrial RNA fractions can also be biological signals indicating elevated respiration.

# %% [markdown]
# We start with calculating the QC covariates:
#
# * total number of counts per cell
# * number of expressed genes per cell
# * fraction of mitochondrial reads per cell

# %%
sc.pp.calculate_qc_metrics(adata, inplace=True)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 26598 × 34802
#     obs: 'sample', 'condition', 'area', 'age', 'donor', 'sequencing batch', 'sequencing id', 'sex', 'APOE genotype', 'brain area number', 'running number', 'donor_v2', 'donor_v2_area', 'tech_sample', 'cell_type', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes'
#     var: 'ensemble_id', 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'

# %% [markdown]
# ## Visualize different metadata

# %% [markdown]
# The following is the library size distribution. Library size is defined as the total mRNA count in each cell.

# %%
plt.hist(adata.obs["log1p_total_counts"], 100)
plt.xlabel("log1p library size", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# The following is the distribution of number of genes expressed in each cell. It should be correlated with library size above.

# %%
plt.hist(adata.obs["log1p_n_genes_by_counts"], bins=100)
plt.xlabel("Log of num. genes per cell", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
# plt.title('Histogram of number of genes expressed in each cell', fontsize = 14)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
fig = plt.figure(figsize=(8 * 3, 6 * 1))
ax = fig.add_subplot(1, 3, 1)
ax.hist(adata.obs["log1p_total_counts"], bins=100)
ax.set_xlabel("Log-library size", fontsize=14)
ax.set_ylabel("Frequency", fontsize=14)
ax.set_title("Histogram of log library size", fontsize=14)

ax = fig.add_subplot(1, 3, 2)
ax.hist(adata.obs["log1p_n_genes_by_counts"], bins=100)
ax.set_xlabel("Log of num. genes per cell", fontsize=14)
ax.set_ylabel("Frequency", fontsize=14)
ax.set_title("Histogram of number of genes expressed in each cell", fontsize=14)

ax = fig.add_subplot(1, 3, 3)
x = adata.obs["log1p_total_counts"]
y = adata.obs["log1p_n_genes_by_counts"]
ax.scatter(x, y, s=5)
ax.set_ylabel("Log of num. genes per cell", fontsize=14)
ax.set_xlabel("Log library size", fontsize=14)
corr_coef = np.corrcoef(x, y)[0, 1]
ax.set_title("Correlation = " + str(round(corr_coef, 3)), fontsize=14)
# Out:
# Text(0.5, 1.0, 'Correlation = 0.956')

# %% [markdown]
# ## Visualize %MT

# %% [markdown]
# Compute the fraction of mitochondrial genes. Note: mitochondrial genes in human start with 'MT-'.

# %%
mt_genes = adata.var_names[adata.var_names.str.startswith("MT-")]

# %%
mt_genes
# Out:
# Index(['MT-TF', 'MT-RNR1', 'MT-TV', 'MT-RNR2', 'MT-TL1', 'MT-ND1', 'MT-TI',
#        'MT-TQ', 'MT-TM', 'MT-ND2', 'MT-TW', 'MT-TA', 'MT-TN', 'MT-TC', 'MT-TY',
#        'MT-CO1', 'MT-TS1', 'MT-TD', 'MT-CO2', 'MT-TK', 'MT-ATP8', 'MT-ATP6',
#        'MT-CO3', 'MT-TG', 'MT-ND3', 'MT-TR', 'MT-ND4L', 'MT-ND4', 'MT-TH',
#        'MT-TS2', 'MT-TL2', 'MT-ND5', 'MT-ND6', 'MT-TE', 'MT-CYB', 'MT-TT',
#        'MT-TP'],
#       dtype='object', name='gene_symbol')

# %%
# compute the % of mito content by dividing the above result by library size
row_sum_adata_mito = np.sum(adata[:, mt_genes].X.toarray(), axis=1)
adata.obs["mt_pct_content"] = row_sum_adata_mito / adata.obs["total_counts"] * 100

# %%
fig = plt.figure(figsize=(8 * 3, 6 * 1))
ax = fig.add_subplot(1, 3, 1)
ax.hist(adata.obs["mt_pct_content"], 100)
ax.set_xlabel("% MT-content", fontsize=14)
ax.set_ylabel("Frequency", fontsize=14)

ax = fig.add_subplot(1, 3, 2)
ax.scatter(adata.obs["log1p_total_counts"], adata.obs["mt_pct_content"])
ax.set_xlabel("Log library size", fontsize=14)
ax.set_ylabel("% MT-content", fontsize=14)

ax = fig.add_subplot(1, 3, 3)
ax.scatter(adata.obs["log1p_n_genes_by_counts"], adata.obs["mt_pct_content"])
ax.set_xlabel("Log num. genes per cell", fontsize=14)
ax.set_ylabel("% MT-content", fontsize=14)
# Out:
# Text(0, 0.5, '% MT-content')

# %% [markdown]
# As you can see from the left plot, there are only very few cells with substantial MT content. And from the figure on the right, you can see that those cells with high MT-content are also the ones with low number of genes expressed (or library size). As such, we argue to remove these high MT-cells.
#
# The following code removes cells with MT-content greater than 30%.

# %%
adata_clean = adata[adata.obs["mt_pct_content"] < 30, :]

# %%
adata_clean
# Out:
# View of AnnData object with n_obs × n_vars = 26598 × 34802
#     obs: 'sample', 'condition', 'area', 'age', 'donor', 'sequencing batch', 'sequencing id', 'sex', 'APOE genotype', 'brain area number', 'running number', 'donor_v2', 'donor_v2_area', 'tech_sample', 'cell_type', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'mt_pct_content'
#     var: 'ensemble_id', 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'

# %%
# just double check: there must be no cell with MT > 30
plt.hist(adata_clean.obs["mt_pct_content"], 100)
plt.xlabel("% MT-content", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# NOTE: For the sake of exposition, we will continue with original `adata` (i.e. will not use `adata_clean`).

# %% [markdown]
# ## Visualize gene metadata

# %%
plt.hist(adata.var["n_cells_by_counts"], bins=100)
plt.xlabel("Number of cells a gene is expressed in", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.title("Histogram of number of cells each gene is expressed in", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Histogram of number of cells each gene is expressed in')

# %% [markdown]
# We see that there are a lot of genes that are expressed in 0 cells. We can zoom in the plot to verify and we will remove them.

# %%
fig = plt.figure(figsize=(8 * 3, 6 * 1))
ax = fig.add_subplot(1, 3, 1)
ax.hist(adata.var["n_cells_by_counts"], bins=100)
ax.set_xlabel("Number of cells a gene is expressed in", fontsize=14)
ax.set_ylabel("Frequency", fontsize=14)
ax.set_title("Histogram of number of cells each gene is expressed in", fontsize=14)

ax = fig.add_subplot(1, 3, 2)
ax.hist(np.log(adata.var["n_cells_by_counts"] + 1), bins=100)
ax.set_xlabel("Log - Number of cells a gene is expressed in", fontsize=14)
ax.set_ylabel("Frequency", fontsize=14)
ax.set_title(
    "Histogram of log of number of cells each gene is expressed in", fontsize=14
)

ax = fig.add_subplot(1, 3, 3)
ax.hist(np.log(adata.var["n_cells_by_counts"] + 1), bins=100)
ax.set_xlabel("Log - Number of cells a gene is expressed in", fontsize=14)
ax.set_ylabel("Frequency, ylim trimmed", fontsize=14)
ax.set_title(
    "Histogram of log of number of cells each gene is expressed in", fontsize=14
)
ax.set_ylim([0, 1000])
# Out:
# (0.0, 1000.0)

# %% [markdown]
# Remove lowly expressed genes:

# %%
sc.pp.filter_genes(adata, min_cells=np.exp(4))

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 26598 × 33152
#     obs: 'sample', 'condition', 'area', 'age', 'donor', 'sequencing batch', 'sequencing id', 'sex', 'APOE genotype', 'brain area number', 'running number', 'donor_v2', 'donor_v2_area', 'tech_sample', 'cell_type', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'mt_pct_content'
#     var: 'ensemble_id', 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells'

# %% [markdown]
# # Other QC metrics

# %% [markdown]
# ## Ribosomal RNA content

# %%
# Identify ribo-genes
ribo_genes = adata.var_names[adata.var_names.str.startswith(("RPS", "RPL"))]
print(ribo_genes)
# Out:
# Index(['RPL13AP9', 'RPL21P23', 'RPS6KC1', 'RPL11', 'RPL36P6', 'RPS8',
#        'RPSAP21', 'RPS27', 'RPS15AP10', 'RPL7AP16',
#        ...
#        'RPL10P16', 'RPS4Y1', 'RPL3', 'RPL7P52', 'RPL4P6', 'RPS19BP1',
#        'RPL32P5', 'RPL13AP26', 'RPS17P16', 'RPS5P2'],
#       dtype='object', name='gene_symbol', length=277)

# %%
# now we need the row sum of the subsetted data to compute % ribo content
row_sum_adata_ribo = np.sum(adata[:, ribo_genes].X.toarray(), axis=1)

# %%
# compute the % of ribo content by dividing the above result by library size
adata.obs["ribo_pct_content"] = row_sum_adata_ribo / adata.obs["total_counts"] * 100

# %%
fig = plt.figure(figsize=(8 * 3, 6 * 1))
ax = fig.add_subplot(1, 3, 1)
ax.hist(adata.obs["ribo_pct_content"], 100)
ax.set_xlabel("% Ribo-content", fontsize=14)
ax.set_ylabel("Frequency", fontsize=14)

ax = fig.add_subplot(1, 3, 2)
ax.scatter(adata.obs["log1p_total_counts"], adata.obs["ribo_pct_content"])
ax.set_xlabel("Log library size", fontsize=14)
ax.set_ylabel("% Ribo-content", fontsize=14)

ax = fig.add_subplot(1, 3, 3)
ax.scatter(adata.obs["log1p_n_genes_by_counts"], adata.obs["ribo_pct_content"])
ax.set_xlabel("Log num. genes per cell", fontsize=14)
ax.set_ylabel("% Ribo-content", fontsize=14)
# Out:
# Text(0, 0.5, '% Ribo-content')

# %% [markdown]
# ## (Optional but often recommended) Remove ribosomal genes

# %% [markdown]
# Many publications often remove ribosomal genes from the beginning of their analysis because there are very limited publications which highlight their important application beisdes cell homeostasis. Here is an example of code of how you can remove ribosomal genes from your data:

# %%
adata_clean = adata[:, ~adata.var_names.str.startswith(("RPS", "RPL"))]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 26598 × 33152
#     obs: 'sample', 'condition', 'area', 'age', 'donor', 'sequencing batch', 'sequencing id', 'sex', 'APOE genotype', 'brain area number', 'running number', 'donor_v2', 'donor_v2_area', 'tech_sample', 'cell_type', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'mt_pct_content', 'ribo_pct_content'
#     var: 'ensemble_id', 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells'

# %%
adata_clean
# Out:
# View of AnnData object with n_obs × n_vars = 26598 × 32875
#     obs: 'sample', 'condition', 'area', 'age', 'donor', 'sequencing batch', 'sequencing id', 'sex', 'APOE genotype', 'brain area number', 'running number', 'donor_v2', 'donor_v2_area', 'tech_sample', 'cell_type', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'mt_pct_content', 'ribo_pct_content'
#     var: 'ensemble_id', 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells'

# %% [markdown]
# NOTE: For the sake of exposition, we will continue with original `adata` (i.e. will not use `adata_clean`).

# %% [markdown]
# ## Doublet score

# %% [markdown]
# Let us estimate the amount of doublets in the dataset. Here, we use the tool `scrublet` that simulates doublet gene expression profiles based on the data. We apply it for each sample separately.

# %%
# filtering/preprocessing parameters:
min_counts = 2
min_cells = 3
vscore_percentile = 85
n_pc = 50

# doublet detector parameters:
expected_doublet_rate = 0.02
sim_doublet_ratio = 3
n_neighbors = 15


scrub = scr.Scrublet(
    counts_matrix=adata.X,
    n_neighbors=n_neighbors,
    sim_doublet_ratio=sim_doublet_ratio,
    expected_doublet_rate=expected_doublet_rate,
)

doublet_scores, predicted_doublets = scrub.scrub_doublets(
    min_counts=min_counts,
    min_cells=min_cells,
    n_prin_comps=n_pc,
    use_approx_neighbors=True,
    get_doublet_neighbor_parents=False,
)

adata.obs["doublet_score"] = doublet_scores
adata.obs["doublet"] = predicted_doublets
# Out:
# Preprocessing...
# C:\Users\lisap\anaconda3\envs\workshop_2025\Lib\site-packages\scrublet\helper_functions.py:252: RuntimeWarning: invalid value encountered in sqrt
#   CV_input = np.sqrt(b);
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.13
# Detected doublet rate = 1.0%
# Estimated detectable doublet fraction = 68.7%
# Overall doublet rate:
# 	Expected   = 2.0%
# 	Estimated  = 1.5%
# Elapsed time: 58.1 seconds

# %% [markdown]
# **Tasks:** Plot the doublet score as a histogram and as violin plot.

# %%
#from matplotlib import rcParams
#import seaborn as sb

rcParams["figure.figsize"] = (6, 6)
sb.distplot(adata.obs["doublet_score"])  # histogram of the doublet score

rcParams["figure.figsize"] = (15, 7)
sc.pl.violin(adata, keys="doublet_score", groupby="cell_type")  # violin plot of the doublet score
# Out:
# C:\Users\lisap\AppData\Local\Temp\ipykernel_10568\1520519866.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(adata.obs["doublet_score"])  # histogram of the doublet score

# %% [markdown]
# **Tasks:** Plot the doublet score per cell type.
#
# Usually, OPCs have higher doublet score.

# %% [markdown]
# ### Filtering doublets
#
# Scrublet proposed a different threshold than we would choose based upon the histogram plot of the doublet scores.
#
# **Tasks:** Decide on a threshold to filter doublets.

# %%
thr = 0.2
ix_filt = adata.obs['doublet_score']<=thr

adata = adata[ix_filt].copy()
print('Number of cells after doublet filter: {:d}'.format(adata.n_obs))
# Out:
# Number of cells after doublet filter: 26451

# %% [markdown]
# # Data Normalization

# %% [markdown]
# One of the most common normalization methods is median library size normalization followed by log-transformation. Median library size normalization is inspired from normalization techniques in bulk data (Transcript Per Million or TPM normalization). This approach aims to normalize the library size of all cells to the same value, which is usually set to be the median library size in the data. The assumption here is that all cells in a sample should have the same total number of RNA counts. Obviously this is not necessarily an adequate assumption and in many circumstances is false (for example, a sample with cells of different sizes or at different stages of activation can have different total RNA). However, this is still the most common kind of normalization being used.
#
# The normalization step is followed by a log transformation of the data. This step is done primarily to normalize for the differences in gene expression scales. Of note, scRNA-seq data is massively undersampled, which means many of the entries are 0 thus taking log of the data can be problematic. As such, it is typical to add a non-zero pseudocount (typically 0.1 or 1) to the data. It is generally wise to ensure that zeros remain as zeros post log-transformation. So, it is common to add 1 to the data before taking log of the data: `adata.X = np.log(adata.X + 1)` or adding and subtracting 0.1: `adata.X = np.log(adata.X + 0.1) - np.log(0.1)`. Either way, zeros before log remain as zeros.
#
# Before we apply this normalization step, one very important note on Scanpy's data structure: The main data on which processing is to be done is stored in `adata.X`. So if we normalize the data in place then the original raw data will be replaced by the new normalized counts and we will lose the original counts. To avoid this from happening, we will store the original raw counts in adata.layers as follows. It is wise to save original counts for later, as we may require them for downstream analysis (e.g. count based factor analysis methods).

# %%
adata.layers["raw_data"] = adata.X.copy()

# %% [markdown]
# Now that we have made a copy of the original counts, we can go ahead and apply Scanpy's normalization function.

# %%
sc.pp.normalize_total(adata, inplace=True)

# %% [markdown]
# We can now log transform the data as follows (Note - we did not save normalized data in layers as raw_data because we can always recompute it if needed):

# %%
sc.pp.log1p(adata)

# %% [markdown]
# # Save results for future

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 26598 × 33152
#     obs: 'sample', 'condition', 'area', 'age', 'donor', 'sequencing batch', 'sequencing id', 'sex', 'APOE genotype', 'brain area number', 'running number', 'donor_v2', 'donor_v2_area', 'tech_sample', 'cell_type', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'mt_pct_content', 'ribo_pct_content', 'doublet_score', 'doublet'
#     var: 'ensemble_id', 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells'
#     uns: 'log1p'
#     layers: 'raw_data'

# %%
#adata.write_h5ad(data_path + "processed/processed_data.h5ad")

# %% [markdown]
# # Loading saved data

# %%
#adata = sc.read_h5ad(data_path + "processed/processed_data.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 26598 × 33152
#     obs: 'sample', 'condition', 'area', 'age', 'donor', 'sequencing batch', 'sequencing id', 'sex', 'APOE genotype', 'brain area number', 'running number', 'donor_v2', 'donor_v2_area', 'tech_sample', 'cell_type', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'mt_pct_content', 'ribo_pct_content', 'doublet_score', 'doublet'
#     var: 'ensemble_id', 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells'
#     uns: 'log1p'
#     layers: 'raw_data'
